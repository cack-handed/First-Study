# %% [markdown]
# # savefig 跟在最后的绘图命令后，保存图像格式
# ## latex限定EPS，HTML限定SVG，word限定EMF（第一个笔记有说明，此处再次重复。由于论文需要，矢量图需要很高的质量

# %%
# %load my_first_chart.py
import matplotlib.pyplot as plt
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square value',color='gray')
plt.text(2,4.5,'second')
plt.text(4,16.5,'fourth')
plt.text(1.1,12,'$y=x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.2})
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['first series','second series','third series'],loc = 2) #legend 顺序与plot顺序一致

plt.savefig('my_chart.EPS') ##注意必须写在这句话里面
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# %run my_first_chart.py
