# %% [markdown]
# # 在其他子图中显示子图

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 绘制坐标轴

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax = fig.add_axes([0.6,0.6,0.25,0.25])

# %% [markdown]
# ## 传入真实数据

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax = fig.add_axes([0.6,0.6,0.25,0.25])

x1=np.arange(10)
y1=np.random.randint(0,10,10)
x2=np.arange(10)
y2=np.random.randint(0,10,10)

ax.plot(x1,y1)
inner_ax.plot(x2,y2)

# %% [markdown]
# # 子图网络

# %% [markdown]
# ## 构建/划分

# %%
gs = plt.GridSpec(3,3)
fig = plt.figure(figsize=(3,5))
fig.add_subplot(gs[1,:2]) #(1,0+1,1)
fig.add_subplot(gs[0,:2]) #(0,0+0,1)
fig.add_subplot(gs[2,0]) #(2,0)
fig.add_subplot(gs[:2,2]) #(0,2+1,2)
fig.add_subplot(gs[2,1:]) #(2,1+2,2)

# %% [markdown]
# ## 使用

# %%
gs = plt.GridSpec(3,3)
fig = plt.figure(figsize=(7,7))
s1=fig.add_subplot(gs[1,:2]) #(1,0+1,1)
s2=fig.add_subplot(gs[0,:2]) #(0,0+0,1)
s3=fig.add_subplot(gs[2,0]) #(2,0)
s4=fig.add_subplot(gs[:2,2]) #(0,2+1,2)
s5=fig.add_subplot(gs[2,1:]) #(2,1+2,2)

x1=np.array([1,3,2,5])
y1=np.array([4,3,7,2])
x2 = np.arange(5)
y2 = np.array([3,2,4,6,4])

s1.plot(x1,y1,'r')
s2.bar(x2,y2)
s3.barh(x2,y2,color='g')
s4.plot(x2,y2,'k')
s5.plot(x1,y1,'b^',x2,y2,'yo')
